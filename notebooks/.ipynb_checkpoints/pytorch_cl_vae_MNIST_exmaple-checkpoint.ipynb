# %%
from sklearn.datasets import fetch_mldata
from sklearn import preprocessing
from scipy.stats import norm
import numpy as np
import numpy.random as random
import matplotlib.pyplot as plt
import torch
# %matplotlib inline

import os
import sys
print("Current working dir: ", os.getcwd())
print("Initial path: ", sys.path)
sys.path.append("../")
print()
print("Updated path: ", sys.path)
from src.pytorch_cl_vae.model import ClVaeModel
# Out:
# Current working dir:  /home/seanny/classifying_autoencoders/notebooks
# Initial path:  ['', '/home/seanny/catkin_ws/devel/lib/python2.7/dist-packages', '/opt/ros/kinetic/lib/python2.7/dist-packages', '/home/seanny/anaconda2/envs/python3.5/lib/python35.zip', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5/plat-linux', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5/lib-dynload', '/home/seanny/.local/lib/python3.5/site-packages', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5/site-packages', '/home/seanny/roboschool', '/home/seanny/DeepRL', '/home/seanny/gym-aero', '/home/seanny/baselines', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5/site-packages/IPython/extensions', '/home/seanny/.ipython']
#
# Updated path:  ['', '/home/seanny/catkin_ws/devel/lib/python2.7/dist-packages', '/opt/ros/kinetic/lib/python2.7/dist-packages', '/home/seanny/anaconda2/envs/python3.5/lib/python35.zip', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5/plat-linux', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5/lib-dynload', '/home/seanny/.local/lib/python3.5/site-packages', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5/site-packages', '/home/seanny/roboschool', '/home/seanny/DeepRL', '/home/seanny/gym-aero', '/home/seanny/baselines', '/home/seanny/anaconda2/envs/python3.5/lib/python3.5/site-packages/IPython/extensions', '/home/seanny/.ipython', '../']

# %% [markdown]
# ## 1 - Load the model

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
fname = '../data/models/cl_vae_mnist_last.pt'
model = ClVaeModel.load_from_ckpt(fname)
print("Model loaded.")
# Out:
# Model loaded.

# %% [markdown]
# ## 2 - Load MNIST

# %%
datadir = '../data'
mnist = fetch_mldata('MNIST original', data_home=datadir)
mnist.data = mnist.data / 255
num_samples, input_dim = mnist.data.shape
num_classes = len(np.unique(mnist.target))
lb = preprocessing.LabelBinarizer()
lb.fit(mnist.target)
print('MNIST db has been successfully loaded, stored in the: "{}"'.format(datadir + '/mldata'))
# Out:
# MNIST db has been successfully loaded, stored in the: "../data/mldata"

# %%
num_examples = 2000
idxs = random.randint(0, num_samples-1, num_examples)
x = mnist.data[idxs]
y = mnist.target[idxs]
y_probs = lb.transform(y)
x_batch = torch.from_numpy(x).float().to(device)
ws_batch = [torch.from_numpy(y_probs).float().to(device)]

z, _, _ = model.encode(x_batch, ws_batch)

import src.pytorch_cl_vae.utils as utils
plt.figure(figsize=(12,12))
utils.plot_latent(z.detach().cpu().numpy(), y)

# %% [markdown]
# ## 3 - Get some examples to work with

# %%
num_examples = 2
idxs = random.randint(0, num_samples-1, num_examples)
x = mnist.data[idxs]
y = mnist.target[idxs]
y_probs = lb.transform(y)
for i in range(x.shape[0]):
    plt.figure()
    img = x[i].reshape([int(np.sqrt(x.shape[-1]))]*2)
    plt.title(y[i])
    plt.imshow(img, cmap='Greys')
    
plt.show()

# %% [markdown]
# ## 4 - Reconstruction check

# %%
# Encode
x_batch = torch.from_numpy(x).float().to(device)
ws_batch = [torch.from_numpy(y_probs).float().to(device)]

z, z_mean, z_log_var = model.encode(x_batch, ws_batch)
print("{}\n{}\n{}".format(z, z_mean, z_log_var.exp().sqrt()))
x_decoded = model.decode(z, ws_batch)

x_decoded = x_decoded.detach().cpu().numpy()

for i in range(x_decoded.shape[0]):
    plt.figure()
    img = x_decoded[i].reshape([int(np.sqrt(x_decoded.shape[-1]))]*2)
    plt.title(y[i])
    plt.imshow(img, cmap='Greys')
    
plt.show()
# Out:
# tensor([[-0.9766,  1.6631],
#         [-1.0456,  1.6500]], device='cuda:0')
# tensor([[-0.9686,  1.4525],
#         [ 0.1073,  0.8970]], device='cuda:0')
# tensor([[ 0.5301,  0.4142],
#         [ 0.7717,  0.6248]], device='cuda:0')
# torch.Size([2, 10])
# torch.Size([2, 12])

# %% [markdown]
# ## 5 - Generate with fixed ws

# %%
n = 25
w_fixed = ws_batch[0].detach().cpu().numpy()
print(w_fixed.shape)
w_fixed = np.tile(y_probs[0][:], (n**2, 1))

print(w_fixed.shape)
z_random = random.normal(size=(z[0].shape))
z1 = norm.ppf(np.linspace(0.00001, 0.99999, n))
zx, zy = np.meshgrid(z1, z1)
z_random = np.stack((zx, zy), axis=-1).reshape((-1, 2))
print(z_random.shape)

z_random = torch.from_numpy(z_random).float().to(device)
w_fixed = [torch.from_numpy(w_fixed).float().to(device)]

print("z_random: ", z_random.size())
print("w_fixed: ", [w.size() for w in w_fixed])
x_decoded = model.decode(z_random, w_fixed)

x_decoded = x_decoded.detach().cpu().numpy()

final_img = np.zeros((n*int(np.sqrt(x_decoded.shape[-1])), n*int(np.sqrt(x_decoded.shape[-1]))))

img_size = int(np.sqrt(x_decoded.shape[-1]))
plt.figure(figsize=(14,14))
for i in range(x_decoded.shape[0]):
#     
    img = x_decoded[i].reshape([int(np.sqrt(x_decoded.shape[-1]))]*2)
    final_img[(i % n) * img_size : (i % n + 1) * img_size, (i // n) * img_size : (i // n + 1) * img_size ] = img
#     plt.title(w_fixed[0][i].max(0)[1].detach().numpy())
plt.imshow(final_img, cmap='Greys')

plt.show()
# Out:
# (2, 10)
# (625, 10)
# (625, 2)
# z_random:  torch.Size([625, 2])
# w_fixed:  [torch.Size([625, 10])]
# torch.Size([625, 10])
# torch.Size([625, 12])

# %% [markdown]
# ## 6 - Generate with fixed z

# %%
ws_random = np.identity(ws_batch[0].shape[-1])
z_fixed = np.tile(z[1], (ws_random.shape[0], 1))

ws_random = [torch.from_numpy(ws_random).float().to(device)]
z_fixed = torch.from_numpy(z_fixed).float().to(device)
x_decoded = model.decode(z_fixed, ws_random)
x_decoded = x_decoded.detach().cpu().numpy()

for i in range(x_decoded.shape[0]):
    plt.figure()
    img = x_decoded[i].reshape([int(np.sqrt(x_decoded.shape[-1]))]*2)
    plt.title(i)
    plt.imshow(img, cmap='Greys')
    
plt.show()
# Out:
# torch.Size([10, 10])
# torch.Size([10, 12])
